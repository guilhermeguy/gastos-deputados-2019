# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermeguy/gastos-deputados-2019/blob/master/Gastos_camara_deputados_2019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
gastos = pd.read_csv('./dataset/Ano-2019.csv', sep=';')
gastos.head()
# Out:
#   txNomeParlamentar  ideCadastro  nuCarteiraParlamentar  nuLegislatura sgUF  \
# 0        LID.GOV-CD          NaN                    NaN           2015  NaN
# 1        LID.GOV-CD          NaN                    NaN           2019  NaN
# 2        LID.GOV-CD          NaN                    NaN           2019  NaN
# 3        LID.GOV-CD          NaN                    NaN           2019  NaN
# 4        LID.GOV-CD          NaN                    NaN           2019  NaN
#
#   sgPartido  codLegislatura  numSubCota  \
# 0       NaN              55          13
# 1       NaN              56          13
# 2       NaN              56          13
# 3       NaN              56          13
# 4       NaN              56          13
#
#                                  txtDescricao  numEspecificacaoSubCota  ...  \
# 0  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                        0  ...
# 1  FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                        0  ...
# ...

# %%
gastos['sgPartido'].value_counts()
# Out:
# PT               12507
# PSL               7581
# PP                6753
# MDB               6315
# PSD               5902
# PSDB              5193
# PSB               5013
# PL                4782
# PDT               4339
# DEM               4062
# PRB               4034
# PODE              1768
# SOLIDARIEDADE     1738
# PTB               1551
# PSOL              1334
# CIDADANIA         1260
# PROS              1207
# PCdoB             1143
# AVANTE            1024
# PSC                879
# NOVO               855
# PV                 673
# PATRI              585
# PR                 444
# PHS                214
# PMN                124
# PRP                112
# S.PART.            110
# REDE                82
# PPS                 36
# Name: sgPartido, dtype: int64
